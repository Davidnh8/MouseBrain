# %%
import sys
import numpy as np
import time
import pickle
import pandas as pd
import copy
import matplotlib.pyplot as plt

import allensdk
import pandas as pd

# %%
from allensdk.core.mouse_connectivity_cache import MouseConnectivityCache

# %% [markdown]
# # Mouse Connectivity
#
# This notebook analyzes the mouse connectivity data for the purpose of calculating the information flow in the brain. Some definitions are in order

# %% [markdown]
# projection density = sum of detected pixels / sum of all pixels in division
# projection energy = sum of detected pixel intensity / sum of all pixels in division
# injection_fraction = fraction of pixels belonging to manually annotated injection site
# injection_density = density of detected pixels within the manually annotated injection site
# injection_energy = energy of detected pixels within the manually annotated injection site
# data_mask = binary mask indicating if a voxel contains valid data (0=invalid, 1=valid). Only valid voxels should be used for analysis

# %% [markdown]
# ## Fetch all the Experiment list

# %%
# MouseConnectivityCache allows access to data stored within
mcc=MouseConnectivityCache(manifest_file='connectivity/mouse_connectivity_manifest.json')

#get the id of all experiments.
#Create one for dataframe and the other in terms of dictionary
experiment_list = mcc.get_experiments(dataframe=True)
experiment_list_dict=mcc.get_experiments(dataframe=False)
# Out:
# ---------------------------------------------------------------------------
# ManifestVersionError                      Traceback (most recent call last)
# <ipython-input-3-d5f2418e3c48> in <module>()
#       1 # MouseConnectivityCache allows access to data stored within
# ----> 2 mcc=MouseConnectivityCache(manifest_file='connectivity/mouse_connectivity_manifest.json')
#       3
#       4 #get the id of all experiments.
#       5 #Create one for dataframe and the other in terms of dictionary
#
# C:\Users\David\Anaconda3\envs\p2\lib\site-packages\allensdk\core\mouse_connectivity_cache.pyc in __init__(self, resolution, cache, manifest_file, ccf_version, base_uri, version)
#     137         super(MouseConnectivityCache, self).__init__(
#     138             resolution, reference_space_key=ccf_version, cache=cache,
# --> 139             manifest=manifest_file, version=version)
#     140
#     141         self.api = MouseConnectivityApi(base_uri=base_uri)
#
# C:\Users\David\Anaconda3\envs\p2\lib\site-packages\allensdk\core\reference_space_cache.pyc in __init__(self, resolution, reference_space_key, **kwargs)
#      68             kwargs['base_uri'] = None
#      69
# ---> 70         super(ReferenceSpaceCache, self).__init__(**kwargs)
#      71
#      72         self.resolution = resolution
#
# C:\Users\David\Anaconda3\envs\p2\lib\site-packages\allensdk\api\cache.pyc in __init__(self, manifest, cache, version, **kwargs)
#      72                  **kwargs):
#      73         self.cache = cache
# ---> 74         self.load_manifest(manifest, version)
#      75
#      76     def get_cache_path(self, file_name, manifest_key, *args):
#
# C:\Users\David\Anaconda3\envs\p2\lib\site-packages\allensdk\api\cache.pyc in load_manifest(self, file_name, version)
#     128                                             " and it will be regenerated for you the next"
#     129                                             " time you instantiate this class.") % (file_name, e.found_version, e.version),
# --> 130                                            e.version, e.found_version)
#     131         else:
#     132             self.manifest = None
#
# ManifestVersionError: Your manifest file (connectivity/mouse_connectivity_manifest.json) is out of date (version '1.3' vs '1.2').  Please remove this file and it will be regenerated for you the next time you instantiate this class.

# %% [markdown]
# where the former is a pandas.dataframe while the latter is a list that contains dictionary with respect to each experiment where the keys describe their properties

# %%
experiment_list[:3]

# %% [markdown]
# Each experiment contains the following properties

# %%
for i in experiment_list_dict[0].keys():
    print(i)

# %% [markdown]
# We wish to create a list that contains the experiment id

# %%
exp_id=[]
for i in experiment_list_dict:
    exp_id.append(i['id'])

# %%
print '%s number of experiments' %len(exp_id)

# %% [markdown]
# ## Annotation Volume
# We download annotation volume, a matrix that denotes the structure type at a specific spatial coordinate (index of the matrix)

# %%
annt=mcc.get_annotation_volume()[0]

# %% [markdown]
# the annotation volume has the shape

# %%
annt.shape

# %%
annt_structures=[]
for i in range(annt.shape[0]):
    for j in range(annt.shape[1]):
        for k in range(annt.shape[2]):
            if annt[i,j,k] not in annt_structures:
                annt_structures.append(annt[i,j,k])

# %% [markdown]
# ## Structure_tree

# %%
structure_tree=mcc.get_structure_tree()

# %% [markdown]
# Allenmouse structure ontology is organized as a tree where each edge indicates the physical containment
#
# Structure tree can be used to fetch properties of a given structure, for example for thalamus, we can retrieve:

# %%
pd.DataFrame(structure_tree.get_structures_by_name(['Thalamus','Hypothalamus']))

# %%
for i in structure_tree.get_structures_by_name(['Thalamus'])[0]:
    print(i)

# %% [markdown]
# ## structure set
# AllenMouse SDK provides a convenient way to group structures together through the use of structure sets. Therefore fetching a structure is relatively easy.

# %%
from allensdk.api.queries.ontologies_api import OntologiesApi

#initialize oapi_inst instance
oapi_inst=OntologiesApi()

# %%
structure_set_ids=structure_tree.get_structure_sets()
structure_set=pd.DataFrame(oapi_inst.get_structure_sets(structure_set_ids))
structure_set

# %% [markdown]
# Here our interest is in the projection research, therefore we fetch the summary structures from 184527634

# %%
projection_structures=structure_tree.get_structures_by_set_id([184527634])
pd.DataFrame(projection_structures)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6d9cf9b1af40> in <module>()
# ----> 1 projection_structures=structure_tree.get_structures_by_set_id([184527634])
#       2 pd.DataFrame(projection_structures)
#
# NameError: name 'structure_tree' is not defined

# %% [markdown]
# ### how many structures in each?

# %%
structure_set[structure_set.columns[1]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a509034314ad> in <module>()
# ----> 1 structure_set[structure_set.columns[1]]
#
# NameError: name 'structure_set' is not defined

# %%
printme={'experiment id':[],'number of structures':[]}

for i in structure_set[structure_set.columns[1]]:
    printme['experiment id'].append(i)
    printme['number of structures'].append(len(structure_tree.get_structures_by_set_id([i])))
print pd.DataFrame(printme)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ef02a06a73bf> in <module>()
#       1 printme={'experiment id':[],'number of structures':[]}
#       2
# ----> 3 for i in structure_set[structure_set.columns[1]]:
#       4     printme['experiment id'].append(i)
#       5     printme['number of structures'].append(len(structure_tree.get_structures_by_set_id([i])))
#
# NameError: name 'structure_set' is not defined

# %% [markdown]
# # Maps
#
# Each structure can be denoted by all kinds of variables such as its id, acronym, or its full name. Therefore it is convenient to define maps that will take care of this. We want the map to function as a converter between variables.

# %%
projection_structures=pd.DataFrame(projection_structures)

acronym=projection_structures['acronym'].values.tolist()
acronym_to_id={}
acronym_to_name={}
acronym_to_volume={}

for i in range(len(acronym)):
    a=projection_structures['acronym'][i]
    b=projection_structures['structure_id_path'][i][-1]
    c=projection_structures['name'][i]
    acronym_to_id[a]=b
    acronym_to_name[a]=c

# %% [markdown]
# ### structure volumes
#
# as far as I am aware, getting the structure volume is not straight forward

# %% [markdown]
# define inverse map for the dictionary

# %%
def invert_me(arg):
    """inverts a map
        args:
            arg(dictionary): input dictionary
        returns:
            inverted input dictionary"""
    return {v: k for k,v in arg.iteritems()}

# %%
id_to_acronym=invert_me(acronym_to_id)
id_to_name=invert_me(acronym_to_name)

# %%
def varmap(structures,inp,outp,):
    """"""
    valid_type_list=['acronym','id','name','list']
    if inp not in valid_type_list or outp not in valid_type_list:
        raise ValueError("invalid type")
    
    #single conversion
    
    if type(inp)=='acronym':
        return structures[]
    elif type(inp)=='id':
        return structures[]
    elif type(inp)=='name':
        return 
    
    
    #list conversion
    elif type(inp)=='list':

# %% [markdown]
# # Comparison between annotation volume and structure_tree
#
# First we make sure the set of structures obtained from the structure_tree and the annotation volume contain each other:

# %%
projection_structures
# Out:
# [{'acronym': u'TMv',
#   'graph_id': 1,
#   'graph_order': 775,
#   'id': 1,
#   'name': u'Tuberomammillary nucleus, ventral part',
#   'rgb_triplet': [255, 76, 62],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 467, 331, 557, 1],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    688152364,
#    184527634,
#    167587189,
#    687527945,
#    114512891]},
#  {'acronym': u'SSp-m6b',
#   'graph_id': 1,
#   'graph_order': 78,
#   'id': 2,
#   'name': u'Primary somatosensory area, mouth, layer 6b',
#   'rgb_triplet': [24, 128, 100],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 345, 2],
#   'structure_set_ids': [667481450, 12, 184527634, 691663206]},
#  {'acronym': u'IC',
#   'graph_id': 1,
#   'graph_order': 812,
#   'id': 4,
#   'name': u'Inferior colliculus',
#   'rgb_triplet': [255, 122, 255],
#   'structure_id_path': [997, 8, 343, 313, 339, 4],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    10,
#    12,
#    688152365,
#    184527634,
#    167587189,
#    114512891,
#    114512892,
#    112905813]},
#  {'acronym': u'int',
#   'graph_id': 1,
#   'graph_order': 1201,
#   'id': 6,
#   'name': u'internal capsule',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 983, 784, 6],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'PSV',
#   'graph_id': 1,
#   'graph_order': 889,
#   'id': 7,
#   'name': u'Principal sensory nucleus of the trigeminal',
#   'rgb_triplet': [255, 174, 111],
#   'structure_id_path': [997, 8, 343, 1065, 771, 1132, 7],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    10,
#    12,
#    688152366,
#    184527634,
#    112905813,
#    114512891,
#    167587189]},
#  {'acronym': u'grey',
#   'graph_id': 1,
#   'graph_order': 1,
#   'id': 8,
#   'name': u'Basic cell groups and regions',
#   'rgb_triplet': [191, 218, 227],
#   'structure_id_path': [997, 8],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    184527634,
#    112905813,
#    114512891,
#    114512892]},
#  {'acronym': u'SSp-tr6a',
#   'graph_id': 1,
#   'graph_order': 91,
#   'id': 9,
#   'name': u'Primary somatosensory area, trunk, layer 6a',
#   'rgb_triplet': [24, 128, 100],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 361, 9],
#   'structure_set_ids': [667481449, 184527634, 12, 691663206]},
#  {'acronym': u'SCig',
#   'graph_id': 1,
#   'graph_order': 834,
#   'id': 10,
#   'name': u'Superior colliculus, motor related, intermediate gray layer',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 294, 10],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'IF',
#   'graph_id': 1,
#   'graph_order': 869,
#   'id': 12,
#   'name': u'Interfascicular nucleus raphe',
#   'rgb_triplet': [255, 166, 255],
#   'structure_id_path': [997, 8, 343, 313, 348, 165, 12],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152365,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'PT',
#   'graph_id': 1,
#   'graph_order': 693,
#   'id': 15,
#   'name': u'Parataenial nucleus',
#   'rgb_triplet': [255, 144, 159],
#   'structure_id_path': [997, 8, 343, 1129, 549, 856, 571, 15],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    688152363,
#    12,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'SCiw',
#   'graph_id': 1,
#   'graph_order': 833,
#   'id': 17,
#   'name': u'Superior colliculus, motor related, intermediate white layer',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 294, 17],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'IG',
#   'graph_id': 1,
#   'graph_order': 491,
#   'id': 19,
#   'name': u'Induseum griseum',
#   'rgb_triplet': [126, 208, 75],
#   'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 19],
#   'structure_set_ids': [3,
#    112905828,
#    691663206,
#    688152359,
#    687527945,
#    12,
#    184527634,
#    167587189]},
#  {'acronym': u'ENTl2',
#   'graph_id': 1,
#   'graph_order': 496,
#   'id': 20,
#   'name': u'Entorhinal area, lateral part, layer 2',
#   'rgb_triplet': [50, 184, 37],
#   'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 909, 918, 20],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'lotg',
#   'graph_id': 1,
#   'graph_order': 1107,
#   'id': 21,
#   'name': u'lateral olfactory tract, general',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 967, 840, 21],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'PTLp',
#   'graph_id': 1,
#   'graph_order': 339,
#   'id': 22,
#   'name': u'Posterior parietal association areas',
#   'rgb_triplet': [0, 159, 172],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 22],
#   'structure_set_ids': [3,
#    112905828,
#    691663206,
#    12,
#    184527634,
#    112905813,
#    114512891]},
#  {'acronym': u'AAA',
#   'graph_id': 1,
#   'graph_order': 593,
#   'id': 23,
#   'name': u'Anterior amygdalar area',
#   'rgb_triplet': [128, 192, 226],
#   'structure_id_path': [997, 8, 567, 623, 477, 278, 23],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    184527634,
#    167587189,
#    688152361,
#    114512891]},
#  {'acronym': u'SCdg',
#   'graph_id': 1,
#   'graph_order': 831,
#   'id': 26,
#   'name': u'Superior colliculus, motor related, deep gray layer',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 294, 26],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'IGL',
#   'graph_id': 1,
#   'graph_order': 705,
#   'id': 27,
#   'name': u'Intergeniculate leaflet of the lateral geniculate complex',
#   'rgb_triplet': [255, 144, 159],
#   'structure_id_path': [997, 8, 343, 1129, 549, 856, 1014, 27],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    688152363,
#    12,
#    184527634,
#    167587189]},
#  {'acronym': u'ENTl6a',
#   'graph_id': 1,
#   'graph_order': 505,
#   'id': 28,
#   'name': u'Entorhinal area, lateral part, layer 6a',
#   'rgb_triplet': [50, 184, 37],
#   'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 909, 918, 28],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'PVa',
#   'graph_id': 1,
#   'graph_order': 731,
#   'id': 30,
#   'name': u'Periventricular hypothalamic nucleus, anterior part',
#   'rgb_triplet': [255, 93, 80],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 157, 30],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    688152364,
#    184527634,
#    167587189,
#    687527945]},
#  {'acronym': u'ACA',
#   'graph_id': 1,
#   'graph_order': 220,
#   'id': 31,
#   'name': u'Anterior cingulate area',
#   'rgb_triplet': [64, 166, 102],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 31],
#   'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891]},
#  {'acronym': u'VISp6a',
#   'graph_id': 1,
#   'graph_order': 190,
#   'id': 33,
#   'name': u'Primary visual area, layer 6a',
#   'rgb_triplet': [8, 133, 140],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 385, 33],
#   'structure_set_ids': [667481449, 184527634, 396673091, 12, 691663206]},
#  {'acronym': u'III',
#   'graph_id': 1,
#   'graph_order': 854,
#   'id': 35,
#   'name': u'Oculomotor nucleus',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 35],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    10,
#    12,
#    688152365,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'GU1',
#   'graph_id': 1,
#   'graph_order': 108,
#   'id': 36,
#   'name': u'Gustatory areas, layer 1',
#   'rgb_triplet': [0, 156, 117],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 1057, 36],
#   'structure_set_ids': [667481440, 184527634, 12, 691663206]},
#  {'acronym': u'PVH',
#   'graph_id': 1,
#   'graph_order': 720,
#   'id': 38,
#   'name': u'Paraventricular hypothalamic nucleus',
#   'rgb_triplet': [255, 93, 80],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 157, 38],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    10,
#    688152364,
#    184527634,
#    167587189,
#    687527945,
#    114512891]},
#  {'acronym': u'ACAd',
#   'graph_id': 1,
#   'graph_order': 226,
#   'id': 39,
#   'name': u'Anterior cingulate area, dorsal part',
#   'rgb_triplet': [64, 166, 102],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 31, 39],
#   'structure_set_ids': [112905828,
#    688152357,
#    691663206,
#    687527945,
#    12,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'VISpm2/3',
#   'graph_id': 1,
#   'graph_order': 201,
#   'id': 41,
#   'name': u'posteromedial visual area, layer 2/3',
#   'rgb_triplet': [8, 133, 140],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 533, 41],
#   'structure_set_ids': [667481441, 184527634, 396673091, 12, 691663206]},
#  {'acronym': u'SCdw',
#   'graph_id': 1,
#   'graph_order': 832,
#   'id': 42,
#   'name': u'Superior colliculus, motor related, deep white layer',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 294, 42],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'ILA',
#   'graph_id': 1,
#   'graph_order': 245,
#   'id': 44,
#   'name': u'Infralimbic area',
#   'rgb_triplet': [89, 179, 99],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 44],
#   'structure_set_ids': [3,
#    112905828,
#    688152357,
#    691663206,
#    687527945,
#    12,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'mfbsma',
#   'graph_id': 1,
#   'graph_order': 1277,
#   'id': 46,
#   'name': u'mammillary related',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 991, 824, 46],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'ACAv',
#   'graph_id': 1,
#   'graph_order': 232,
#   'id': 48,
#   'name': u'Anterior cingulate area, ventral part',
#   'rgb_triplet': [64, 166, 102],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 31, 48],
#   'structure_set_ids': [112905828,
#    688152357,
#    691663206,
#    687527945,
#    12,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'PRC',
#   'graph_id': 1,
#   'graph_order': 839,
#   'id': 50,
#   'name': u'Precommissural nucleus',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 795, 50],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'ILM',
#   'graph_id': 1,
#   'graph_order': 696,
#   'id': 51,
#   'name': u'Intralaminar nuclei of the dorsal thalamus',
#   'rgb_triplet': [255, 144, 159],
#   'structure_id_path': [997, 8, 343, 1129, 549, 856, 51],
#   'structure_set_ids': [12, 184527634, 114512891, 112905828, 691663206]},
#  {'acronym': u'ENTl3',
#   'graph_id': 1,
#   'graph_order': 500,
#   'id': 52,
#   'name': u'Entorhinal area, lateral part, layer 3',
#   'rgb_triplet': [50, 184, 37],
#   'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 909, 918, 52],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'mfb',
#   'graph_id': 1,
#   'graph_order': 1262,
#   'id': 54,
#   'name': u'medial forebrain bundle',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 991, 824, 54],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'ACB',
#   'graph_id': 1,
#   'graph_order': 575,
#   'id': 56,
#   'name': u'Nucleus accumbens',
#   'rgb_triplet': [128, 205, 248],
#   'structure_id_path': [997, 8, 567, 623, 477, 493, 56],
#   'structure_set_ids': [112905828,
#    691663206,
#    688152361,
#    10,
#    12,
#    184527634,
#    167587189,
#    687527945,
#    114512891]},
#  {'acronym': u'MT',
#   'graph_id': 1,
#   'graph_order': 863,
#   'id': 58,
#   'name': u'Medial terminal nucleus of the accessory optic tract',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 58],
#   'structure_set_ids': [184527634,
#    112905828,
#    688152365,
#    691663206,
#    167587189]},
#  {'acronym': u'IMD',
#   'graph_id': 1,
#   'graph_order': 684,
#   'id': 59,
#   'name': u'Intermediodorsal nucleus of the thalamus',
#   'rgb_triplet': [255, 144, 159],
#   'structure_id_path': [997, 8, 343, 1129, 549, 856, 444, 59],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    688152363,
#    12,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'mlf',
#   'graph_id': 1,
#   'graph_order': 1120,
#   'id': 62,
#   'name': u'medial longitudinal fascicle',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 967, 832, 62],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'PVHd',
#   'graph_id': 1,
#   'graph_order': 782,
#   'id': 63,
#   'name': u'Paraventricular hypothalamic nucleus, descending division',
#   'rgb_triplet': [255, 76, 62],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 467, 63],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    688152364,
#    184527634,
#    167587189,
#    687527945,
#    114512891]},
#  {'acronym': u'AD',
#   'graph_id': 1,
#   'graph_order': 679,
#   'id': 64,
#   'name': u'Anterodorsal nucleus',
#   'rgb_triplet': [255, 144, 159],
#   'structure_id_path': [997, 8, 343, 1129, 549, 856, 239, 64],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    10,
#    688152363,
#    12,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'LT',
#   'graph_id': 1,
#   'graph_order': 861,
#   'id': 66,
#   'name': u'Lateral terminal nucleus of the accessory optic tract',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 66],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152365,
#    184527634,
#    167587189]},
#  {'acronym': u'INC',
#   'graph_id': 1,
#   'graph_order': 840,
#   'id': 67,
#   'name': u'Interstitial nucleus of Cajal',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 795, 67],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'FRP1',
#   'graph_id': 1,
#   'graph_order': 7,
#   'id': 68,
#   'name': u'Frontal pole, layer 1',
#   'rgb_triplet': [38, 143, 69],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 184, 68],
#   'structure_set_ids': [667481440, 184527634, 12, 691663206]},
#  {'acronym': u'ADP',
#   'graph_id': 1,
#   'graph_order': 735,
#   'id': 72,
#   'name': u'Anterodorsal preoptic nucleus',
#   'rgb_triplet': [255, 85, 71],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 141, 72],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    688152364,
#    184527634,
#    167587189,
#    687527945,
#    114512891]},
#  {'acronym': u'VISl6a',
#   'graph_id': 1,
#   'graph_order': 183,
#   'id': 74,
#   'name': u'Lateral visual area, layer 6a',
#   'rgb_triplet': [8, 133, 140],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 409, 74],
#   'structure_set_ids': [667481449, 184527634, 396673091, 12, 691663206]},
#  {'acronym': u'DT',
#   'graph_id': 1,
#   'graph_order': 862,
#   'id': 75,
#   'name': u'Dorsal terminal nucleus of the accessory optic tract',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 75],
#   'structure_set_ids': [184527634,
#    112905828,
#    167587189,
#    691663206,
#    688152365]},
#  {'acronym': u'mcp',
#   'graph_id': 1,
#   'graph_order': 1179,
#   'id': 78,
#   'name': u'middle cerebellar peduncle',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 960, 752, 78],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'IO',
#   'graph_id': 1,
#   'graph_order': 977,
#   'id': 83,
#   'name': u'Inferior olivary complex',
#   'rgb_triplet': [255, 179, 217],
#   'structure_id_path': [997, 8, 343, 1065, 354, 370, 83],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    10,
#    12,
#    688152367,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'PL6a',
#   'graph_id': 1,
#   'graph_order': 243,
#   'id': 84,
#   'name': u'Prelimbic area, layer 6a',
#   'rgb_triplet': [47, 168, 80],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 972, 84],
#   'structure_set_ids': [667481449, 184527634, 12, 691663206]},
#  {'acronym': u'AHN',
#   'graph_id': 1,
#   'graph_order': 757,
#   'id': 88,
#   'name': u'Anterior hypothalamic nucleus',
#   'rgb_triplet': [255, 76, 62],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 467, 88],
#   'structure_set_ids': [112905828,
#    691663206,
#    688152364,
#    12,
#    184527634,
#    167587189,
#    687527945,
#    114512891]},
#  {'acronym': u'IP',
#   'graph_id': 1,
#   'graph_order': 1098,
#   'id': 91,
#   'name': u'Interposed nucleus',
#   'rgb_triplet': [255, 253, 188],
#   'structure_id_path': [997, 8, 512, 519, 91],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152368,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'moV',
#   'graph_id': 1,
#   'graph_order': 1126,
#   'id': 93,
#   'name': u'motor root of the trigeminal nerve',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 967, 901, 93],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'AI',
#   'graph_id': 1,
#   'graph_order': 278,
#   'id': 95,
#   'name': u'Agranular insular area',
#   'rgb_triplet': [33, 152, 102],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 95],
#   'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891]},
#  {'acronym': u'DCO',
#   'graph_id': 1,
#   'graph_order': 941,
#   'id': 96,
#   'name': u'Dorsal cochlear nucleus',
#   'rgb_triplet': [255, 165, 210],
#   'structure_id_path': [997, 8, 343, 1065, 354, 386, 607, 96],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152367,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'TEa1',
#   'graph_id': 1,
#   'graph_order': 361,
#   'id': 97,
#   'name': u'Temporal association areas, layer 1',
#   'rgb_triplet': [21, 176, 179],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 541, 97],
#   'structure_set_ids': [667481440, 184527634, 12, 691663206]},
#  {'acronym': u'SEZ',
#   'graph_id': 1,
#   'graph_order': 1295,
#   'id': 98,
#   'name': u'subependymal zone',
#   'rgb_triplet': [170, 170, 170],
#   'structure_id_path': [997, 73, 81, 98],
#   'structure_set_ids': [10, 184527634, 691663206]},
#  {'acronym': u'IPN',
#   'graph_id': 1,
#   'graph_order': 870,
#   'id': 100,
#   'name': u'Interpeduncular nucleus',
#   'rgb_triplet': [255, 166, 255],
#   'structure_id_path': [997, 8, 343, 313, 348, 165, 100],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    10,
#    12,
#    688152365,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'VCO',
#   'graph_id': 1,
#   'graph_order': 942,
#   'id': 101,
#   'name': u'Ventral cochlear nucleus',
#   'rgb_triplet': [255, 165, 210],
#   'structure_id_path': [997, 8, 343, 1065, 354, 386, 607, 101],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152367,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'nst',
#   'graph_id': 1,
#   'graph_order': 1221,
#   'id': 102,
#   'name': u'nigrostriatal tract',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 1000, 760, 102],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'AId',
#   'graph_id': 1,
#   'graph_order': 279,
#   'id': 104,
#   'name': u'Agranular insular area, dorsal part',
#   'rgb_triplet': [33, 152, 102],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 95, 104],
#   'structure_set_ids': [112905828,
#    688152357,
#    691663206,
#    687527945,
#    12,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'SOCm',
#   'graph_id': 1,
#   'graph_order': 904,
#   'id': 105,
#   'name': u'Superior olivary complex, medial part',
#   'rgb_triplet': [255, 174, 111],
#   'structure_id_path': [997, 8, 343, 1065, 771, 1132, 398, 105],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'ISN',
#   'graph_id': 1,
#   'graph_order': 979,
#   'id': 106,
#   'name': u'Inferior salivatory nucleus',
#   'rgb_triplet': [255, 179, 217],
#   'structure_id_path': [997, 8, 343, 1065, 354, 370, 106],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152367,
#    184527634,
#    167587189]},
#  {'acronym': u'chpl',
#   'graph_id': 1,
#   'graph_order': 1296,
#   'id': 108,
#   'name': u'choroid plexus',
#   'rgb_triplet': [170, 170, 170],
#   'structure_id_path': [997, 73, 81, 108],
#   'structure_set_ids': [10, 184527634, 691663206]},
#  {'acronym': u'AIp',
#   'graph_id': 1,
#   'graph_order': 285,
#   'id': 111,
#   'name': u'Agranular insular area, posterior part',
#   'rgb_triplet': [33, 152, 102],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 95, 111],
#   'structure_set_ids': [112905828,
#    688152357,
#    691663206,
#    687527945,
#    12,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'SSp-ll2/3',
#   'graph_id': 1,
#   'graph_order': 67,
#   'id': 113,
#   'name': u'Primary somatosensory area, lower limb, layer 2/3',
#   'rgb_triplet': [24, 128, 100],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 337, 113],
#   'structure_set_ids': [667481441, 184527634, 12, 691663206]},
#  {'acronym': u'SOCl',
#   'graph_id': 1,
#   'graph_order': 905,
#   'id': 114,
#   'name': u'Superior olivary complex, lateral part',
#   'rgb_triplet': [255, 174, 111],
#   'structure_id_path': [997, 8, 343, 1065, 771, 1132, 398, 114],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'IV',
#   'graph_id': 1,
#   'graph_order': 857,
#   'id': 115,
#   'name': u'Trochlear nucleus',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 115],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152365,
#    184527634,
#    167587189]},
#  {'acronym': u'och',
#   'graph_id': 1,
#   'graph_order': 1116,
#   'id': 117,
#   'name': u'optic chiasm',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 967, 848, 117],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'PVi',
#   'graph_id': 1,
#   'graph_order': 732,
#   'id': 118,
#   'name': u'Periventricular hypothalamic nucleus, intermediate part',
#   'rgb_triplet': [255, 93, 80],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 157, 118],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    688152364,
#    184527634,
#    167587189,
#    687527945]},
#  {'acronym': u'AIv',
#   'graph_id': 1,
#   'graph_order': 291,
#   'id': 119,
#   'name': u'Agranular insular area, ventral part',
#   'rgb_triplet': [33, 152, 102],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 95, 119],
#   'structure_set_ids': [112905828,
#    688152357,
#    691663206,
#    687527945,
#    12,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'AIp1',
#   'graph_id': 1,
#   'graph_order': 286,
#   'id': 120,
#   'name': u'Agranular insular area, posterior part, layer 1',
#   'rgb_triplet': [33, 152, 102],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 95, 111, 120],
#   'structure_set_ids': [667481440, 184527634, 12, 691663206]},
#  {'acronym': u'VISl6b',
#   'graph_id': 1,
#   'graph_order': 184,
#   'id': 121,
#   'name': u'Lateral visual area, layer 6b',
#   'rgb_triplet': [8, 133, 140],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 409, 121],
#   'structure_set_ids': [667481450, 396673091, 12, 184527634, 691663206]},
#  {'acronym': u'POR',
#   'graph_id': 1,
#   'graph_order': 903,
#   'id': 122,
#   'name': u'Superior olivary complex, periolivary region',
#   'rgb_triplet': [255, 174, 111],
#   'structure_id_path': [997, 8, 343, 1065, 771, 1132, 398, 122],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'KF',
#   'graph_id': 1,
#   'graph_order': 891,
#   'id': 123,
#   'name': u'Koelliker-Fuse subnucleus',
#   'rgb_triplet': [255, 174, 111],
#   'structure_id_path': [997, 8, 343, 1065, 771, 1132, 867, 123],
#   'structure_set_ids': [114512892, 184527634, 12, 112905813, 691663206]},
#  {'acronym': u'opt',
#   'graph_id': 1,
#   'graph_order': 1117,
#   'id': 125,
#   'name': u'optic tract',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 967, 848, 125],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'PVp',
#   'graph_id': 1,
#   'graph_order': 749,
#   'id': 126,
#   'name': u'Periventricular hypothalamic nucleus, posterior part',
#   'rgb_triplet': [255, 85, 71],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 141, 126],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    688152364,
#    184527634,
#    167587189,
#    687527945,
#    114512891]},
#  {'acronym': u'AM',
#   'graph_id': 1,
#   'graph_order': 676,
#   'id': 127,
#   'name': u'Anteromedial nucleus',
#   'rgb_triplet': [255, 144, 159],
#   'structure_id_path': [997, 8, 343, 1129, 549, 856, 239, 127],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    688152363,
#    12,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'MRN',
#   'graph_id': 1,
#   'graph_order': 826,
#   'id': 128,
#   'name': u'Midbrain reticular nucleus',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 128],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152365,
#    184527634,
#    112905813,
#    114512891,
#    114512892,
#    167587189]},
#  {'acronym': u'LA',
#   'graph_id': 1,
#   'graph_order': 561,
#   'id': 131,
#   'name': u'Lateral amygdalar nucleus',
#   'rgb_triplet': [144, 235, 141],
#   'structure_id_path': [997, 8, 567, 688, 703, 131],
#   'structure_set_ids': [112905828,
#    691663206,
#    688152360,
#    687527945,
#    12,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'PL6b',
#   'graph_id': 1,
#   'graph_order': 244,
#   'id': 132,
#   'name': u'Prelimbic area, layer 6b',
#   'rgb_triplet': [47, 168, 80],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 972, 132],
#   'structure_set_ids': [667481450, 12, 184527634, 691663206]},
#  {'acronym': u'PVpo',
#   'graph_id': 1,
#   'graph_order': 750,
#   'id': 133,
#   'name': u'Periventricular hypothalamic nucleus, preoptic part',
#   'rgb_triplet': [255, 85, 71],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 141, 133],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    688152364,
#    184527634,
#    167587189,
#    687527945]},
#  {'acronym': u'AMB',
#   'graph_id': 1,
#   'graph_order': 970,
#   'id': 135,
#   'name': u'Nucleus ambiguus',
#   'rgb_triplet': [255, 179, 217],
#   'structure_id_path': [997, 8, 343, 1065, 354, 370, 135],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    10,
#    12,
#    688152367,
#    184527634,
#    112905813,
#    167587189]},
#  {'acronym': u'IRN',
#   'graph_id': 1,
#   'graph_order': 978,
#   'id': 136,
#   'name': u'Intermediate reticular nucleus',
#   'rgb_triplet': [255, 179, 217],
#   'structure_id_path': [997, 8, 343, 1065, 354, 370, 136],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152367,
#    184527634,
#    112905813,
#    114512891,
#    114512892,
#    167587189]},
#  {'acronym': u'LAT',
#   'graph_id': 1,
#   'graph_order': 667,
#   'id': 138,
#   'name': u'Lateral group of the dorsal thalamus',
#   'rgb_triplet': [255, 144, 159],
#   'structure_id_path': [997, 8, 343, 1129, 549, 856, 138],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    184527634,
#    112905813,
#    114512891,
#    114512892]},
#  {'acronym': u'ENTl5',
#   'graph_id': 1,
#   'graph_order': 503,
#   'id': 139,
#   'name': u'Entorhinal area, lateral part, layer 5',
#   'rgb_triplet': [50, 184, 37],
#   'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 909, 918, 139],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'PVR',
#   'graph_id': 1,
#   'graph_order': 734,
#   'id': 141,
#   'name': u'Periventricular region',
#   'rgb_triplet': [255, 85, 71],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 141],
#   'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891]},
#  {'acronym': u'AMBv',
#   'graph_id': 1,
#   'graph_order': 972,
#   'id': 143,
#   'name': u'Nucleus ambiguus, ventral division',
#   'rgb_triplet': [255, 179, 217],
#   'structure_id_path': [997, 8, 343, 1065, 354, 370, 135, 143],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'PRNr',
#   'graph_id': 1,
#   'graph_order': 931,
#   'id': 146,
#   'name': u'Pontine reticular nucleus',
#   'rgb_triplet': [255, 195, 149],
#   'structure_id_path': [997, 8, 343, 1065, 771, 1117, 146],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152366,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'GU4',
#   'graph_id': 1,
#   'graph_order': 110,
#   'id': 148,
#   'name': u'Gustatory areas, layer 4',
#   'rgb_triplet': [0, 156, 117],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 1057, 148],
#   'structure_set_ids': [184527634, 12, 667481445, 691663206]},
#  {'acronym': u'PVT',
#   'graph_id': 1,
#   'graph_order': 692,
#   'id': 149,
#   'name': u'Paraventricular nucleus of the thalamus',
#   'rgb_triplet': [255, 144, 159],
#   'structure_id_path': [997, 8, 343, 1129, 549, 856, 571, 149],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    10,
#    688152363,
#    12,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'AOB',
#   'graph_id': 1,
#   'graph_order': 386,
#   'id': 151,
#   'name': u'Accessory olfactory bulb',
#   'rgb_triplet': [157, 240, 210],
#   'structure_id_path': [997, 8, 567, 688, 695, 698, 151],
#   'structure_set_ids': [112905828,
#    688152358,
#    691663206,
#    687527945,
#    10,
#    12,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'PHY',
#   'graph_id': 1,
#   'graph_order': 993,
#   'id': 154,
#   'name': u'Perihypoglossal nuclei',
#   'rgb_triplet': [255, 179, 217],
#   'structure_id_path': [997, 8, 343, 1065, 354, 370, 154],
#   'structure_set_ids': [12, 184527634, 114512891, 112905828, 691663206]},
#  {'acronym': u'LD',
#   'graph_id': 1,
#   'graph_order': 682,
#   'id': 155,
#   'name': u'Lateral dorsal nucleus of thalamus',
#   'rgb_triplet': [255, 144, 159],
#   'structure_id_path': [997, 8, 343, 1129, 549, 856, 239, 155],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    688152363,
#    12,
#    184527634,
#    112905813,
#    114512891,
#    167587189]},
#  {'acronym': u'AUDd6a',
#   'graph_id': 1,
#   'graph_order': 127,
#   'id': 156,
#   'name': u'Dorsal auditory area, layer 6a',
#   'rgb_triplet': [1, 147, 153],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 247, 1011, 156],
#   'structure_set_ids': [667481449, 184527634, 12, 691663206]},
#  {'acronym': u'PVZ',
#   'graph_id': 1,
#   'graph_order': 716,
#   'id': 157,
#   'name': u'Periventricular zone',
#   'rgb_triplet': [255, 93, 80],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 157],
#   'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891]},
#  {'acronym': u'pc',
#   'graph_id': 1,
#   'graph_order': 1121,
#   'id': 158,
#   'name': u'posterior commissure',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 967, 832, 158],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'AON',
#   'graph_id': 1,
#   'graph_order': 390,
#   'id': 159,
#   'name': u'Anterior olfactory nucleus',
#   'rgb_triplet': [84, 191, 148],
#   'structure_id_path': [997, 8, 567, 688, 695, 698, 159],
#   'structure_set_ids': [112905828,
#    691663206,
#    688152358,
#    687527945,
#    10,
#    12,
#    184527634,
#    112905813,
#    114512891,
#    114512892,
#    167587189]},
#  {'acronym': u'LDT',
#   'graph_id': 1,
#   'graph_order': 929,
#   'id': 162,
#   'name': u'Laterodorsal tegmental nucleus',
#   'rgb_triplet': [255, 195, 149],
#   'structure_id_path': [997, 8, 343, 1065, 771, 1117, 162],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152366,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'AIp2/3',
#   'graph_id': 1,
#   'graph_order': 287,
#   'id': 163,
#   'name': u'Agranular insular area, posterior part, layer 2/3',
#   'rgb_triplet': [33, 152, 102],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 95, 111, 163],
#   'structure_set_ids': [667481441, 184527634, 12, 691663206]},
#  {'acronym': u'RAmb',
#   'graph_id': 1,
#   'graph_order': 868,
#   'id': 165,
#   'name': u'Midbrain raphe nuclei',
#   'rgb_triplet': [255, 166, 255],
#   'structure_id_path': [997, 8, 343, 313, 348, 165],
#   'structure_set_ids': [12, 184527634, 114512891, 112905828, 691663206]},
#  {'acronym': u'im',
#   'graph_id': 1,
#   'graph_order': 1213,
#   'id': 14,
#   'name': u'internal medullary lamina of the thalamus',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 983, 896, 14],
#   'structure_set_ids': [184527634]},
#  {'acronym': u'PRP',
#   'graph_id': 1,
#   'graph_order': 996,
#   'id': 169,
#   'name': u'Nucleus prepositus',
#   'rgb_triplet': [255, 179, 217],
#   'structure_id_path': [997, 8, 343, 1065, 354, 370, 154, 169],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152367,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'LGd',
#   'graph_id': 1,
#   'graph_order': 662,
#   'id': 170,
#   'name': u'Dorsal part of the lateral geniculate complex',
#   'rgb_triplet': [255, 128, 132],
#   'structure_id_path': [997, 8, 343, 1129, 549, 864, 1008, 170],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    688152363,
#    12,
#    184527634,
#    112905813,
#    114512891,
#    167587189]},
#  {'acronym': u'PL1',
#   'graph_id': 1,
#   'graph_order': 239,
#   'id': 171,
#   'name': u'Prelimbic area, layer 1',
#   'rgb_triplet': [47, 168, 80],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 972, 171],
#   'structure_set_ids': [667481440, 184527634, 12, 691663206]},
#  {'acronym': u'RCH',
#   'graph_id': 1,
#   'graph_order': 799,
#   'id': 173,
#   'name': u'Retrochiasmatic area',
#   'rgb_triplet': [242, 72, 59],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 290, 173],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    688152364,
#    184527634,
#    167587189,
#    687527945]},
#  {'acronym': u'NR',
#   'graph_id': 1,
#   'graph_order': 995,
#   'id': 177,
#   'name': u'Nucleus of Roller',
#   'rgb_triplet': [255, 179, 217],
#   'structure_id_path': [997, 8, 343, 1065, 354, 370, 154, 177],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152367,
#    184527634,
#    167587189]},
#  {'acronym': u'LGv',
#   'graph_id': 1,
#   'graph_order': 707,
#   'id': 178,
#   'name': u'Ventral part of the lateral geniculate complex',
#   'rgb_triplet': [255, 144, 159],
#   'structure_id_path': [997, 8, 343, 1129, 549, 856, 1014, 178],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    688152363,
#    12,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'GU2/3',
#   'graph_id': 1,
#   'graph_order': 109,
#   'id': 180,
#   'name': u'Gustatory areas, layer 2/3',
#   'rgb_triplet': [0, 156, 117],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 1057, 180],
#   'structure_set_ids': [667481441, 184527634, 12, 691663206]},
#  {'acronym': u'RE',
#   'graph_id': 1,
#   'graph_order': 694,
#   'id': 181,
#   'name': u'Nucleus of reuniens',
#   'rgb_triplet': [255, 144, 159],
#   'structure_id_path': [997, 8, 343, 1129, 549, 856, 571, 181],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    10,
#    688152363,
#    12,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'FRP',
#   'graph_id': 1,
#   'graph_order': 6,
#   'id': 184,
#   'name': u'Frontal pole, cerebral cortex',
#   'rgb_triplet': [38, 143, 69],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 184],
#   'structure_set_ids': [3,
#    112905828,
#    688152357,
#    691663206,
#    687527945,
#    12,
#    184527634,
#    167587189,
#    114512891,
#    112905813]},
#  {'acronym': u'LH',
#   'graph_id': 1,
#   'graph_order': 713,
#   'id': 186,
#   'name': u'Lateral habenula',
#   'rgb_triplet': [255, 144, 159],
#   'structure_id_path': [997, 8, 343, 1129, 549, 856, 958, 186],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    688152363,
#    12,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'GU5',
#   'graph_id': 1,
#   'graph_order': 111,
#   'id': 187,
#   'name': u'Gustatory areas, layer 5',
#   'rgb_triplet': [0, 156, 117],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 1057, 187],
#   'structure_set_ids': [184527634, 12, 691663206, 667481446]},
#  {'acronym': u'AOBgl',
#   'graph_id': 1,
#   'graph_order': 387,
#   'id': 188,
#   'name': u'Accessory olfactory bulb, glomerular layer',
#   'rgb_triplet': [157, 240, 210],
#   'structure_id_path': [997, 8, 567, 688, 695, 698, 151, 188],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'RH',
#   'graph_id': 1,
#   'graph_order': 697,
#   'id': 189,
#   'name': u'Rhomboid nucleus',
#   'rgb_triplet': [255, 144, 159],
#   'structure_id_path': [997, 8, 343, 1129, 549, 856, 51, 189],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    688152363,
#    12,
#    184527634,
#    167587189]},
#  {'acronym': u'PN',
#   'graph_id': 1,
#   'graph_order': 824,
#   'id': 607344830,
#   'name': u'Paranigral nucleus',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 607344830],
#   'structure_set_ids': [184527634,
#    112905828,
#    167587189,
#    691663206,
#    688152365]},
#  {'acronym': u'LHA',
#   'graph_id': 1,
#   'graph_order': 794,
#   'id': 194,
#   'name': u'Lateral hypothalamic area',
#   'rgb_triplet': [242, 72, 59],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 290, 194],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    688152364,
#    184527634,
#    112905813,
#    687527945,
#    114512891,
#    114512892,
#    167587189]},
#  {'acronym': u'AOBgr',
#   'graph_id': 1,
#   'graph_order': 388,
#   'id': 196,
#   'name': u'Accessory olfactory bulb, granular layer',
#   'rgb_triplet': [149, 228, 200],
#   'structure_id_path': [997, 8, 567, 688, 695, 698, 151, 196],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'RL',
#   'graph_id': 1,
#   'graph_order': 879,
#   'id': 197,
#   'name': u'Rostral linear nucleus raphe',
#   'rgb_triplet': [255, 166, 255],
#   'structure_id_path': [997, 8, 343, 313, 348, 165, 197],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152365,
#    184527634,
#    167587189]},
#  {'acronym': u'IPC',
#   'graph_id': 1,
#   'graph_order': 872,
#   'id': 607344838,
#   'name': u'Interpeduncular nucleus, caudal',
#   'rgb_triplet': [255, 166, 255],
#   'structure_id_path': [997, 8, 343, 313, 348, 165, 100, 607344838],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'SSp-bfd2/3',
#   'graph_id': 1,
#   'graph_order': 53,
#   'id': 201,
#   'name': u'Primary somatosensory area, barrel field, layer 2/3',
#   'rgb_triplet': [24, 128, 100],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 329, 201],
#   'structure_set_ids': [667481441, 184527634, 12, 691663206]},
#  {'acronym': u'IPA',
#   'graph_id': 1,
#   'graph_order': 873,
#   'id': 607344842,
#   'name': u'Interpeduncular nucleus, apical',
#   'rgb_triplet': [255, 166, 255],
#   'structure_id_path': [997, 8, 343, 313, 348, 165, 100, 607344842],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'LIN',
#   'graph_id': 1,
#   'graph_order': 980,
#   'id': 203,
#   'name': u'Linear nucleus of the medulla',
#   'rgb_triplet': [255, 179, 217],
#   'structure_id_path': [997, 8, 343, 1065, 354, 370, 203],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152367,
#    184527634,
#    167587189]},
#  {'acronym': u'AOBmi',
#   'graph_id': 1,
#   'graph_order': 389,
#   'id': 204,
#   'name': u'Accessory olfactory bulb, mitral layer',
#   'rgb_triplet': [157, 240, 210],
#   'structure_id_path': [997, 8, 567, 688, 695, 698, 151, 204],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'IPL',
#   'graph_id': 1,
#   'graph_order': 874,
#   'id': 607344846,
#   'name': u'Interpeduncular nucleus, lateral',
#   'rgb_triplet': [255, 166, 255],
#   'structure_id_path': [997, 8, 343, 313, 348, 165, 100, 607344846],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'AP',
#   'graph_id': 1,
#   'graph_order': 937,
#   'id': 207,
#   'name': u'Area postrema',
#   'rgb_triplet': [255, 165, 210],
#   'structure_id_path': [997, 8, 343, 1065, 354, 386, 207],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    10,
#    12,
#    688152367,
#    184527634,
#    167587189]},
#  {'acronym': u'LAV',
#   'graph_id': 1,
#   'graph_order': 1002,
#   'id': 209,
#   'name': u'Lateral vestibular nucleus',
#   'rgb_triplet': [255, 179, 217],
#   'structure_id_path': [997, 8, 343, 1065, 354, 370, 701, 209],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152367,
#    184527634,
#    167587189]},
#  {'acronym': u'LM',
#   'graph_id': 1,
#   'graph_order': 763,
#   'id': 210,
#   'name': u'Lateral mammillary nucleus',
#   'rgb_triplet': [255, 76, 62],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 467, 331, 210],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    688152364,
#    184527634,
#    167587189,
#    687527945,
#    114512891]},
#  {'acronym': u'ACAd2/3',
#   'graph_id': 1,
#   'graph_order': 228,
#   'id': 211,
#   'name': u'Anterior cingulate area, dorsal part, layer 2/3',
#   'rgb_triplet': [64, 166, 102],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 31, 39, 211],
#   'structure_set_ids': [667481441, 184527634, 12, 691663206]},
#  {'acronym': u'RN',
#   'graph_id': 1,
#   'graph_order': 853,
#   'id': 214,
#   'name': u'Red nucleus',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 214],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    10,
#    12,
#    688152365,
#    184527634,
#    112905813,
#    114512891,
#    167587189]},
#  {'acronym': u'APN',
#   'graph_id': 1,
#   'graph_order': 844,
#   'id': 215,
#   'name': u'Anterior pretectal nucleus',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 1100, 215],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152365,
#    184527634,
#    112905813,
#    114512891,
#    167587189]},
#  {'acronym': u'VLPO',
#   'graph_id': 1,
#   'graph_order': 755,
#   'id': 689,
#   'name': u'Ventrolateral preoptic nucleus',
#   'rgb_triplet': [255, 85, 71],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 141, 689],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    688152364,
#    184527634,
#    167587189,
#    687527945]},
#  {'acronym': u'LP',
#   'graph_id': 1,
#   'graph_order': 668,
#   'id': 218,
#   'name': u'Lateral posterior nucleus of the thalamus',
#   'rgb_triplet': [255, 144, 159],
#   'structure_id_path': [997, 8, 343, 1129, 549, 856, 138, 218],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    688152363,
#    12,
#    184527634,
#    112905813,
#    114512891,
#    114512892,
#    167587189]},
#  {'acronym': u'IPRL',
#   'graph_id': 1,
#   'graph_order': 878,
#   'id': 607344862,
#   'name': u'Interpeduncular nucleus, rostrolateral',
#   'rgb_triplet': [255, 166, 255],
#   'structure_id_path': [997, 8, 343, 313, 348, 165, 100, 607344862],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'ARH',
#   'graph_id': 1,
#   'graph_order': 733,
#   'id': 223,
#   'name': u'Arcuate hypothalamic nucleus',
#   'rgb_triplet': [255, 93, 80],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 157, 223],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    10,
#    688152364,
#    184527634,
#    167587189,
#    687527945,
#    114512891]},
#  {'acronym': u'SPIV',
#   'graph_id': 1,
#   'graph_order': 1004,
#   'id': 225,
#   'name': u'Spinal vestibular nucleus',
#   'rgb_triplet': [255, 179, 217],
#   'structure_id_path': [997, 8, 343, 1065, 354, 370, 701, 225],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152367,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'LPO',
#   'graph_id': 1,
#   'graph_order': 795,
#   'id': 226,
#   'name': u'Lateral preoptic area',
#   'rgb_triplet': [242, 72, 59],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 290, 226],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    688152364,
#    184527634,
#    167587189,
#    687527945,
#    114512891]},
#  {'acronym': u'sV',
#   'graph_id': 1,
#   'graph_order': 1127,
#   'id': 229,
#   'name': u'sensory root of the trigeminal nerve',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 967, 901, 229],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'RPA',
#   'graph_id': 1,
#   'graph_order': 1012,
#   'id': 230,
#   'name': u'Nucleus raphe pallidus',
#   'rgb_triplet': [255, 198, 226],
#   'structure_id_path': [997, 8, 343, 1065, 354, 379, 230],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152367,
#    184527634,
#    167587189]},
#  {'acronym': u'AT',
#   'graph_id': 1,
#   'graph_order': 860,
#   'id': 231,
#   'name': u'Anterior tegmental nucleus',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 231],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152365,
#    184527634,
#    167587189]},
#  {'acronym': u'VISal5',
#   'graph_id': 1,
#   'graph_order': 168,
#   'id': 233,
#   'name': u'Anterolateral visual area, layer 5',
#   'rgb_triplet': [8, 133, 140],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 402, 233],
#   'structure_set_ids': [184527634, 396673091, 12, 691663206, 667481446]},
#  {'acronym': u'TEa4',
#   'graph_id': 1,
#   'graph_order': 363,
#   'id': 234,
#   'name': u'Temporal association areas, layer 4',
#   'rgb_triplet': [21, 176, 179],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 541, 234],
#   'structure_set_ids': [184527634, 12, 667481445, 691663206]},
#  {'acronym': u'LRN',
#   'graph_id': 1,
#   'graph_order': 981,
#   'id': 235,
#   'name': u'Lateral reticular nucleus',
#   'rgb_triplet': [255, 179, 217],
#   'structure_id_path': [997, 8, 343, 1065, 354, 370, 235],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152367,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'VISa',
#   'graph_id': 1,
#   'graph_order': 346,
#   'id': 312782546,
#   'name': u'Anterior area',
#   'rgb_triplet': [0, 159, 172],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 22, 312782546],
#   'structure_set_ids': [396673091,
#    112905828,
#    688152357,
#    691663206,
#    687527945,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'RPO',
#   'graph_id': 1,
#   'graph_order': 932,
#   'id': 238,
#   'name': u'Nucleus raphe pontis',
#   'rgb_triplet': [255, 195, 149],
#   'structure_id_path': [997, 8, 343, 1065, 771, 1117, 238],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152366,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'ATN',
#   'graph_id': 1,
#   'graph_order': 674,
#   'id': 239,
#   'name': u'Anterior group of the dorsal thalamus',
#   'rgb_triplet': [255, 144, 159],
#   'structure_id_path': [997, 8, 343, 1129, 549, 856, 239],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    184527634,
#    112905813,
#    114512891]},
#  {'acronym': u'LS',
#   'graph_id': 1,
#   'graph_order': 586,
#   'id': 242,
#   'name': u'Lateral septal nucleus',
#   'rgb_triplet': [144, 203, 237],
#   'structure_id_path': [997, 8, 567, 623, 477, 275, 242],
#   'structure_set_ids': [112905828,
#    691663206,
#    12,
#    184527634,
#    112905813,
#    114512891,
#    114512892]},
#  {'acronym': u'AUDd6b',
#   'graph_id': 1,
#   'graph_order': 128,
#   'id': 243,
#   'name': u'Dorsal auditory area, layer 6b',
#   'rgb_triplet': [1, 147, 153],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 247, 1011, 243],
#   'structure_set_ids': [667481450, 12, 184527634, 691663206]},
#  {'acronym': u'RR',
#   'graph_id': 1,
#   'graph_order': 825,
#   'id': 246,
#   'name': u'Midbrain reticular nucleus, retrorubral area',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 246],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152365,
#    184527634,
#    167587189]},
#  {'acronym': u'AUD',
#   'graph_id': 1,
#   'graph_order': 121,
#   'id': 247,
#   'name': u'Auditory areas',
#   'rgb_triplet': [1, 147, 153],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 247],
#   'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891]},
#  {'acronym': u'AUDpo6a',
#   'graph_id': 1,
#   'graph_order': 148,
#   'id': 249,
#   'name': u'Posterior auditory area, layer 6a',
#   'rgb_triplet': [1, 147, 153],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 247, 1027, 249],
#   'structure_set_ids': [667481449, 184527634, 12, 691663206]},
#  {'acronym': u'LSc',
#   'graph_id': 1,
#   'graph_order': 587,
#   'id': 250,
#   'name': u'Lateral septal nucleus, caudal (caudodorsal) part',
#   'rgb_triplet': [144, 203, 237],
#   'structure_id_path': [997, 8, 567, 623, 477, 275, 242, 250],
#   'structure_set_ids': [112905828,
#    691663206,
#    688152361,
#    10,
#    12,
#    184527634,
#    112905813,
#    687527945,
#    114512891,
#    114512892,
#    167587189]},
#  {'acronym': u'AUDp2/3',
#   'graph_id': 1,
#   'graph_order': 138,
#   'id': 251,
#   'name': u'Primary auditory area, layer 2/3',
#   'rgb_triplet': [1, 147, 153],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 247, 1002, 251],
#   'structure_set_ids': [667481441, 184527634, 12, 691663206]},
#  {'acronym': u'AUDd5',
#   'graph_id': 1,
#   'graph_order': 126,
#   'id': 252,
#   'name': u'Dorsal auditory area, layer 5',
#   'rgb_triplet': [1, 147, 153],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 247, 1011, 252],
#   'structure_set_ids': [184527634, 12, 691663206, 667481446]},
#  {'acronym': u'RSP',
#   'graph_id': 1,
#   'graph_order': 297,
#   'id': 254,
#   'name': u'Retrosplenial area',
#   'rgb_triplet': [26, 166, 152],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 254],
#   'structure_set_ids': [3,
#    112905828,
#    691663206,
#    10,
#    12,
#    184527634,
#    112905813,
#    114512891]},
#  {'acronym': u'AV',
#   'graph_id': 1,
#   'graph_order': 675,
#   'id': 255,
#   'name': u'Anteroventral nucleus of thalamus',
#   'rgb_triplet': [255, 144, 159],
#   'structure_id_path': [997, 8, 343, 1129, 549, 856, 239, 255],
#   'structure_set_ids': [112905828,
# ...
#   'id': 945,
#   'name': u'Primary somatosensory area, upper limb, layer 6a',
#   'rgb_triplet': [24, 128, 100],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 369, 945],
#   'structure_set_ids': [667481449, 184527634, 12, 691663206]},
#  {'acronym': u'MMp',
#   'graph_id': 1,
#   'graph_order': 768,
#   'id': 606826655,
#   'name': u'Medial mammillary nucleus, posterior part',
#   'rgb_triplet': [255, 76, 62],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 467, 331, 491, 606826655],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'bic',
#   'graph_id': 1,
#   'graph_order': 1142,
#   'id': 482,
#   'name': u'brachium of the inferior colliculus',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 967, 933, 948, 482],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'PYR',
#   'graph_id': 1,
#   'graph_order': 1054,
#   'id': 951,
#   'name': u'Pyramus (VIII)',
#   'rgb_triplet': [255, 252, 145],
#   'structure_id_path': [997, 8, 512, 528, 645, 951],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    688152368,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'hbc',
#   'graph_id': 1,
#   'graph_order': 1287,
#   'id': 611,
#   'name': u'habenular commissure',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 991, 824, 1083, 611],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'LC',
#   'graph_id': 1,
#   'graph_order': 928,
#   'id': 147,
#   'name': u'Locus ceruleus',
#   'rgb_triplet': [255, 195, 149],
#   'structure_id_path': [997, 8, 343, 1065, 771, 1117, 147],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    10,
#    12,
#    688152366,
#    184527634,
#    167587189]},
#  {'acronym': u'LRNm',
#   'graph_id': 1,
#   'graph_order': 982,
#   'id': 955,
#   'name': u'Lateral reticular nucleus, magnocellular part',
#   'rgb_triplet': [255, 179, 217],
#   'structure_id_path': [997, 8, 343, 1065, 354, 370, 235, 955],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'IVn',
#   'graph_id': 1,
#   'graph_order': 1122,
#   'id': 911,
#   'name': u'trochlear nerve',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 967, 911],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'fxpo',
#   'graph_id': 1,
#   'graph_order': 1250,
#   'id': 737,
#   'name': u'postcommissural fornix',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 991, 768, 1099, 737],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'ProS',
#   'graph_id': 1,
#   'graph_order': 544,
#   'id': 484682470,
#   'name': u'Prosubiculum',
#   'rgb_triplet': [88, 186, 72],
#   'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 484682470],
#   'structure_set_ids': [112905828,
#    691663206,
#    688152359,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'VNC',
#   'graph_id': 1,
#   'graph_order': 1001,
#   'id': 701,
#   'name': u'Vestibular nuclei',
#   'rgb_triplet': [255, 179, 217],
#   'structure_id_path': [997, 8, 343, 1065, 354, 370, 701],
#   'structure_set_ids': [12, 184527634, 114512891, 112905828, 691663206]},
#  {'acronym': u'cst',
#   'graph_id': 1,
#   'graph_order': 1200,
#   'id': 784,
#   'name': u'corticospinal tract',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 983, 784],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'alv',
#   'graph_id': 1,
#   'graph_order': 1245,
#   'id': 466,
#   'name': u'alveus',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 991, 768, 1099, 466],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'VAL',
#   'graph_id': 1,
#   'graph_order': 644,
#   'id': 629,
#   'name': u'Ventral anterior-lateral complex of the thalamus',
#   'rgb_triplet': [255, 128, 132],
#   'structure_id_path': [997, 8, 343, 1129, 549, 864, 637, 629],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    688152363,
#    12,
#    184527634,
#    112905813,
#    114512891,
#    167587189]},
#  {'acronym': u'VISli1',
#   'graph_id': 1,
#   'graph_order': 207,
#   'id': 312782578,
#   'name': u'Laterointermediate area, layer 1',
#   'rgb_triplet': [8, 133, 140],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 312782574, 312782578],
#   'structure_set_ids': [667481440, 184527634, 396673091, 691663206]},
#  {'acronym': u'VISli6a',
#   'graph_id': 1,
#   'graph_order': 211,
#   'id': 312782594,
#   'name': u'Laterointermediate area, layer 6a',
#   'rgb_triplet': [8, 133, 140],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 312782574, 312782594],
#   'structure_set_ids': [667481449, 184527634, 396673091, 691663206]},
#  {'acronym': u'VISli6b',
#   'graph_id': 1,
#   'graph_order': 212,
#   'id': 312782598,
#   'name': u'Laterointermediate area, layer 6b',
#   'rgb_triplet': [8, 133, 140],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 312782574, 312782598],
#   'structure_set_ids': [184527634, 396673091, 667481450, 691663206]},
#  {'acronym': u'VISrl1',
#   'graph_id': 1,
#   'graph_order': 354,
#   'id': 312782604,
#   'name': u'Rostrolateral area, layer 1',
#   'rgb_triplet': [0, 159, 172],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 22, 417, 312782604],
#   'structure_set_ids': [667481440, 184527634, 396673091, 691663206]},
#  {'acronym': u'st',
#   'graph_id': 1,
#   'graph_order': 1259,
#   'id': 301,
#   'name': u'stria terminalis',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 991, 768, 301],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'VISrl2/3',
#   'graph_id': 1,
#   'graph_order': 355,
#   'id': 312782608,
#   'name': u'Rostrolateral area, layer 2/3',
#   'rgb_triplet': [0, 159, 172],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 22, 417, 312782608],
#   'structure_set_ids': [667481441, 184527634, 396673091, 691663206]},
#  {'acronym': u'mfbse',
#   'graph_id': 1,
#   'graph_order': 1284,
#   'id': 1083,
#   'name': u'epithalamus related',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 991, 824, 1083],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'VISrl4',
#   'graph_id': 1,
#   'graph_order': 356,
#   'id': 312782612,
#   'name': u'Rostrolateral area, layer 4',
#   'rgb_triplet': [0, 159, 172],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 22, 417, 312782612],
#   'structure_set_ids': [184527634, 396673091, 667481445, 691663206]},
#  {'acronym': u'VISrl5',
#   'graph_id': 1,
#   'graph_order': 357,
#   'id': 312782616,
#   'name': u'Rostrolateral area, layer 5',
#   'rgb_triplet': [0, 159, 172],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 22, 417, 312782616],
#   'structure_set_ids': [184527634, 396673091, 667481446, 691663206]},
#  {'acronym': u'VISrl6a',
#   'graph_id': 1,
#   'graph_order': 358,
#   'id': 312782620,
#   'name': u'Rostrolateral area, layer 6a',
#   'rgb_triplet': [0, 159, 172],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 22, 417, 312782620],
#   'structure_set_ids': [667481449, 184527634, 396673091, 691663206]},
#  {'acronym': u'VISrl6b',
#   'graph_id': 1,
#   'graph_order': 359,
#   'id': 312782624,
#   'name': u'Rostrolateral area, layer 6b',
#   'rgb_triplet': [0, 159, 172],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 22, 417, 312782624],
#   'structure_set_ids': [667481450, 396673091, 184527634, 691663206]},
#  {'acronym': u'VISpor',
#   'graph_id': 1,
#   'graph_order': 213,
#   'id': 312782628,
#   'name': u'Postrhinal area',
#   'rgb_triplet': [8, 133, 140],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 312782628],
#   'structure_set_ids': [396673091,
#    112905828,
#    688152357,
#    691663206,
#    687527945,
#    184527634,
#    167587189,
#    114512891]},
#  {'acronym': u'VISpor1',
#   'graph_id': 1,
#   'graph_order': 214,
#   'id': 312782632,
#   'name': u'Postrhinal area, layer 1',
#   'rgb_triplet': [8, 133, 140],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 312782628, 312782632],
#   'structure_set_ids': [667481440, 184527634, 396673091, 691663206]},
#  {'acronym': u'VISpor2/3',
#   'graph_id': 1,
#   'graph_order': 215,
#   'id': 312782636,
#   'name': u'Postrhinal area, layer 2/3',
#   'rgb_triplet': [8, 133, 140],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 312782628, 312782636],
#   'structure_set_ids': [667481441, 184527634, 396673091, 691663206]},
#  {'acronym': u'VISpor4',
#   'graph_id': 1,
#   'graph_order': 216,
#   'id': 312782640,
#   'name': u'Postrhinal area, layer 4',
#   'rgb_triplet': [8, 133, 140],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 312782628, 312782640],
#   'structure_set_ids': [184527634, 396673091, 667481445, 691663206]},
#  {'acronym': u'RPF',
#   'graph_id': 1,
#   'graph_order': 850,
#   'id': 549009203,
#   'name': u'Retroparafascicular nucleus',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 1100, 549009203],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'VISpor5',
#   'graph_id': 1,
#   'graph_order': 217,
#   'id': 312782644,
#   'name': u'Postrhinal area, layer 5',
#   'rgb_triplet': [8, 133, 140],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 312782628, 312782644],
#   'structure_set_ids': [184527634, 396673091, 691663206, 667481446]},
#  {'acronym': u'VISpor6a',
#   'graph_id': 1,
#   'graph_order': 218,
#   'id': 312782648,
#   'name': u'Postrhinal area, layer 6a',
#   'rgb_triplet': [8, 133, 140],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 312782628, 312782648],
#   'structure_set_ids': [667481449, 184527634, 396673091, 691663206]},
#  {'acronym': u'MA3',
#   'graph_id': 1,
#   'graph_order': 855,
#   'id': 549009211,
#   'name': u'Medial accesory oculomotor nucleus',
#   'rgb_triplet': [255, 144, 255],
#   'structure_id_path': [997, 8, 343, 313, 323, 549009211],
#   'structure_set_ids': [184527634,
#    112905828,
#    688152365,
#    691663206,
#    167587189]},
#  {'acronym': u'VISpor6b',
#   'graph_id': 1,
#   'graph_order': 219,
#   'id': 312782652,
#   'name': u'Postrhinal area, layer 6b',
#   'rgb_triplet': [8, 133, 140],
#   'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 312782628, 312782652],
#   'structure_set_ids': [667481450, 396673091, 184527634, 691663206]},
#  {'acronym': u'P5',
#   'graph_id': 1,
#   'graph_order': 920,
#   'id': 549009215,
#   'name': u'Peritrigeminal zone',
#   'rgb_triplet': [255, 186, 134],
#   'structure_id_path': [997, 8, 343, 1065, 771, 987, 549009215],
#   'structure_set_ids': [184527634,
#    112905828,
#    688152366,
#    691663206,
#    167587189]},
#  {'acronym': u'Acs5',
#   'graph_id': 1,
#   'graph_order': 921,
#   'id': 549009219,
#   'name': u'Accessory trigeminal nucleus',
#   'rgb_triplet': [255, 186, 134],
#   'structure_id_path': [997, 8, 343, 1065, 771, 987, 549009219],
#   'structure_set_ids': [184527634,
#    691663206,
#    112905828,
#    167587189,
#    688152366]},
#  {'acronym': u'PC5',
#   'graph_id': 1,
#   'graph_order': 922,
#   'id': 549009223,
#   'name': u'Parvicellular motor 5 nucleus',
#   'rgb_triplet': [255, 186, 134],
#   'structure_id_path': [997, 8, 343, 1065, 771, 987, 549009223],
#   'structure_set_ids': [184527634,
#    112905828,
#    688152366,
#    691663206,
#    167587189]},
#  {'acronym': u'I5',
#   'graph_id': 1,
#   'graph_order': 923,
#   'id': 549009227,
#   'name': u'Intertrigeminal nucleus',
#   'rgb_triplet': [255, 186, 134],
#   'structure_id_path': [997, 8, 343, 1065, 771, 987, 549009227],
#   'structure_set_ids': [184527634,
#    691663206,
#    112905828,
#    167587189,
#    688152366]},
#  {'acronym': u'HATA',
#   'graph_id': 1,
#   'graph_order': 553,
#   'id': 589508447,
#   'name': u'Hippocampo-amygdalar transition area',
#   'rgb_triplet': [51, 185, 50],
#   'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 589508447],
#   'structure_set_ids': [184527634,
#    112905828,
#    167587189,
#    691663206,
#    688152359]},
#  {'acronym': u'Pa5',
#   'graph_id': 1,
#   'graph_order': 962,
#   'id': 589508451,
#   'name': u'Paratrigeminal nucleus',
#   'rgb_triplet': [255, 165, 210],
#   'structure_id_path': [997, 8, 343, 1065, 354, 386, 589508451],
#   'structure_set_ids': [184527634,
#    112905828,
#    167587189,
#    691663206,
#    688152367]},
#  {'acronym': u'FS',
#   'graph_id': 1,
#   'graph_order': 576,
#   'id': 998,
#   'name': u'Fundus of striatum',
#   'rgb_triplet': [128, 205, 248],
#   'structure_id_path': [997, 8, 567, 623, 477, 493, 998],
#   'structure_set_ids': [112905828,
#    691663206,
#    687527945,
#    12,
#    184527634,
#    167587189,
#    688152361]},
#  {'acronym': u'VeCB',
#   'graph_id': 1,
#   'graph_order': 1100,
#   'id': 589508455,
#   'name': u'Vestibulocerebellar nucleus',
#   'rgb_triplet': [255, 253, 188],
#   'structure_id_path': [997, 8, 512, 519, 589508455],
#   'structure_set_ids': [688152368,
#    184527634,
#    112905828,
#    167587189,
#    691663206]},
#  {'acronym': u'ccb',
#   'graph_id': 1,
#   'graph_order': 1198,
#   'id': 484682516,
#   'name': u'corpus callosum, body',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 983, 776, 484682516],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'py',
#   'graph_id': 1,
#   'graph_order': 1207,
#   'id': 190,
#   'name': u'pyramid',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 983, 784, 190],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'DG-mo',
#   'graph_id': 1,
#   'graph_order': 474,
#   'id': 10703,
#   'name': u'Dentate gyrus, molecular layer',
#   'rgb_triplet': [126, 208, 75],
#   'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 726, 10703],
#   'structure_set_ids': [184527634, 12, 691663206]},
#  {'acronym': u'lot',
#   'graph_id': 1,
#   'graph_order': 1108,
#   'id': 665,
#   'name': u'lateral olfactory tract, body',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 967, 840, 21, 665],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'ts',
#   'graph_id': 1,
#   'graph_order': 1145,
#   'id': 237,
#   'name': u'solitary tract',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 967, 917, 237],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'stc',
#   'graph_id': 1,
#   'graph_order': 1260,
#   'id': 484682528,
#   'name': u'commissural branch of stria terminalis',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 991, 768, 301, 484682528],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'SH',
#   'graph_id': 1,
#   'graph_order': 591,
#   'id': 333,
#   'name': u'Septohippocampal nucleus',
#   'rgb_triplet': [144, 203, 237],
#   'structure_id_path': [997, 8, 567, 623, 477, 275, 333],
#   'structure_set_ids': [112905828,
#    691663206,
#    688152361,
#    12,
#    184527634,
#    167587189,
#    687527945]},
#  {'acronym': u'fx',
#   'graph_id': 1,
#   'graph_order': 1252,
#   'id': 436,
#   'name': u'columns of the fornix',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 991, 768, 1099, 737, 436],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'VMPO',
#   'graph_id': 1,
#   'graph_order': 754,
#   'id': 576073699,
#   'name': u'Ventromedial preoptic nucleus',
#   'rgb_triplet': [255, 85, 71],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 141, 576073699],
#   'structure_set_ids': [688152364,
#    184527634,
#    112905828,
#    167587189,
#    691663206]},
#  {'acronym': u'PeF',
#   'graph_id': 1,
#   'graph_order': 798,
#   'id': 576073704,
#   'name': u'Perifornical nucleus',
#   'rgb_triplet': [242, 72, 59],
#   'structure_id_path': [997, 8, 343, 1129, 1097, 290, 576073704],
#   'structure_set_ids': [688152364,
#    184527634,
#    112905828,
#    167587189,
#    691663206]},
#  {'acronym': u'mtg',
#   'graph_id': 1,
#   'graph_order': 1280,
#   'id': 681,
#   'name': u'mammillotegmental tract',
#   'rgb_triplet': [204, 204, 204],
#   'structure_id_path': [997, 1009, 991, 824, 46, 681],
#   'structure_set_ids': [184527634, 691663206]},
#  {'acronym': u'STR',
#   'graph_id': 1,
#   'graph_order': 571,
#   'id': 477,
#   'name': u'Striatum',
#   'rgb_triplet': [152, 214, 249],
#   'structure_id_path': [997, 8, 567, 623, 477],
#   'structure_set_ids': [2,
#    112905828,
#    691663206,
#    12,
#    184527634,
#    112905813,
#    687527670,
#    114512891,
#    114512892]},
#  {'acronym': u'VP',
#   'graph_id': 1,
#   'graph_order': 646,
#   'id': 709,
#   'name': u'Ventral posterior complex of the thalamus',
#   'rgb_triplet': [255, 128, 132],
#   'structure_id_path': [997, 8, 343, 1129, 549, 864, 637, 709],
#   'structure_set_ids': [112905828,
#    691663206,
#    10,
#    12,
#    184527634,
#    112905813,
#    114512891,
#    114512892]}]

# %%
projection_structures=pd.DataFrame(projection_structures)

for index,row in projection_structures.iterrows():
    print(row['id'])
    if row['id'] not in annt_structures:
        print row['id']
# Out:
# 1
# 2
# 4
# 4
# 6
# 7
# 8
# 8
# 9
# 10
# 12
# 15
# 17
# 19
# 20
# 21
# 21
# 22
# 22
# 23
# 26
# 27
# 28
# 30
# 31
# 31
# 33
# 35
# 36
# 38
# 39
# 39
# 41
# 42
# 44
# 44
# 46
# 46
# 48
# 48
# 50
# 51
# 51
# 52
# 54
# 56
# 58
# 59
# 62
# 63
# 64
# 66
# 67
# 68
# 72
# 74
# 75
# 78
# 83
# 84
# 88
# 91
# 93
# 95
# 95
# 96
# 97
# 98
# 100
# 101
# 102
# 104
# 104
# 105
# 106
# 108
# 111
# 111
# 113
# 114
# 115
# 117
# 118
# 119
# 119
# 120
# 121
# 122
# 123
# 125
# 126
# 127
# 127
# 128
# 131
# 132
# 133
# 135
# 135
# 136
# 138
# 138
# 139
# 141
# 141
# 143
# 146
# 148
# 149
# 151
# 151
# 154
# 154
# 155
# 156
# 157
# 157
# 158
# 159
# 162
# 163
# 165
# 165
# 14
# 14
# 169
# 170
# 170
# 171
# 173
# 177
# 178
# 180
# 181
# 184
# 184
# 186
# 187
# 188
# 189
# 607344830
# 194
# 196
# 197
# 607344838
# 201
# 607344842
# 203
# 204
# 607344846
# 207
# 209
# 210
# 211
# 214
# 215
# 689
# 218
# 607344862
# 223
# 225
# 226
# 229
# 230
# 231
# 233
# 234
# 235
# 235
# 312782546
# 312782546
# 238
# 239
# 239
# 242
# 242
# 243
# 246
# 247
# 247
# 249
# 250
# 251
# 252
# 254
# 254
# 255
# 257
# 258
# 260
# 312782550
# 262
# 263
# 266
# 268
# 269
# 271
# 272
# 728
# 274
# 275
# 275
# 278
# 278
# 279
# 280
# 281
# 312782554
# 286
# 287
# 288
# 289
# 290
# 290
# 292
# 294
# 294
# 295
# 295
# 296
# 298
# 302
# 302
# 303
# 304
# 305
# 307
# 312782558
# 310
# 311
# 313
# 314
# 315
# 315
# 318
# 319
# 319
# 320
# 321
# 322
# 322
# 323
# 323
# 325
# 326
# 327
# 328
# 329
# 329
# 330
# 331
# 331
# 332
# 312782562
# 334
# 335
# 336
# 337
# 337
# 338
# 339
# 339
# 341
# 341
# 342
# 343
# 343
# 344
# 345
# 345
# 347
# 348
# 348
# 349
# 350
# 351
# 353
# 353
# 354
# 355
# 356
# 312782566
# 358
# 361
# 361
# 362
# 363
# 364
# 366
# 368
# 369
# 369
# 370
# 370
# 372
# 374
# 375
# 375
# 377
# 378
# 378
# 379
# 379
# 380
# 312782570
# 382
# 385
# 385
# 386
# 386
# 390
# 393
# 394
# 394
# 395
# 395
# 397
# 398
# 398
# 401
# 402
# 402
# 403
# 312782574
# 312782574
# 406
# 406
# 409
# 409
# 412
# 413
# 414
# 417
# 417
# 421
# 422
# 423
# 425
# 425
# 427
# 428
# 430
# 433
# 434
# 437
# 440
# 441
# 442
# 444
# 444
# 445
# 448
# 450
# 451
# 452
# 312782582
# 456
# 461
# 463
# 10704
# 467
# 467
# 469
# 470
# 475
# 475
# 312782586
# 478
# 483
# 484
# 485
# 485
# 1105
# 488
# 491
# 491
# 493
# 493
# 494
# 494
# 500
# 500
# 312782590
# 502
# 503
# 503
# 506
# 507
# 510
# 511
# 511
# 512
# 514
# 514
# 515
# 519
# 519
# 520
# 523
# 526
# 527
# 528
# 528
# 530
# 531
# 533
# 533
# 534
# 536
# 536
# 538
# 10671
# 540
# 541
# 541
# 542
# 543
# 544
# 545
# 545
# 551
# 553
# 556
# 557
# 557
# 558
# 559
# 564
# 565
# 566
# 567
# 567
# 571
# 571
# 573
# 574
# 575
# 496345664
# 577
# 579
# 496345668
# 581
# 582
# 583
# 780
# 587
# 588
# 589
# 589
# 590
# 591
# 593
# 596
# 597
# 598
# 599
# 600
# 601
# 603
# 604
# 605
# 607
# 607
# 608
# 609
# 610
# 443
# 612
# 613
# 614
# 616
# 618
# 618
# 619
# 619
# 620
# 621
# 622
# 623
# 623
# 625
# 628
# 630
# 631
# 631
# 632
# 633
# 634
# 637
# 637
# 638
# 639
# 642
# 643
# 645
# 645
# 647
# 647
# 648
# 649
# 651
# 653
# 654
# 655
# 656
# 657
# 658
# 661
# 662
# 663
# 664
# 667
# 669
# 669
# 670
# 671
# 672
# 673
# 675
# 677
# 677
# 678
# 679
# 680
# 484682524
# 685
# 687
# 688
# 688
# 692
# 693
# 694
# 695
# 695
# 696
# 697
# 698
# 699
# 702
# 703
# 704
# 707
# 711
# 460
# 714
# 714
# 501
# 718
# 720
# 720
# 721
# 723
# 723
# 725
# 726
# 726
# 727
# 706
# 729
# 731
# 731
# 732
# 733
# 735
# 741
# 743
# 744
# 746
# 746
# 749
# 750
# 752
# 752
# 753
# 754
# 755
# 757
# 759
# 760
# 760
# 763
# 765
# 767
# 771
# 772
# 773
# 774
# 778
# 484682508
# 781
# 783
# 484682512
# 786
# 788
# 791
# 792
# 792
# 794
# 795
# 797
# 798
# 800
# 802
# 803
# 804
# 805
# 806
# 809
# 809
# 810
# 811
# 812
# 814
# 816
# 818
# 818
# 819
# 820
# 821
# 822
# 822
# 824
# 824
# 826
# 826
# 827
# 828
# 830
# 831
# 832
# 834
# 835
# 835
# 836
# 838
# 839
# 840
# 840
# 841
# 842
# 843
# 844
# 846
# 847
# 848
# 849
# 850
# 851
# 852
# 854
# 856
# 856
# 857
# 859
# 862
# 864
# 864
# 866
# 867
# 869
# 872
# 873
# 874
# 877
# 877
# 878
# 879
# 879
# 880
# 882
# 884
# 886
# 886
# 888
# 889
# 893
# 894
# 894
# 895
# 895
# 896
# 896
# 897
# 898
# 900
# 901
# 901
# 902
# 903
# 904
# 904
# 905
# 906
# 907
# 908
# 909
# 909
# 910
# 912
# 914
# 916
# 918
# 918
# 919
# 920
# 920
# 182305689
# 182305689
# 922
# 922
# 924
# 182305693
# 926
# 926
# 927
# 928
# 928
# 929
# 930
# 606826651
# 932
# 932
# 182305701
# 934
# 934
# 935
# 936
# 182305705
# 938
# 938
# 939
# 940
# 182305709
# 942
# 942
# 943
# 944
# 182305713
# 946
# 948
# 948
# 949
# 950
# 560581559
# 952
# 954
# 560581563
# 956
# 957
# 958
# 958
# 959
# 960
# 960
# 961
# 962
# 963
# 964
# 965
# 966
# 967
# 967
# 968
# 969
# 970
# 971
# 972
# 972
# 973
# 974
# 975
# 976
# 977
# 978
# 606826659
# 980
# 981
# 982
# 983
# 983
# 984
# 985
# 985
# 986
# 987
# 987
# 988
# 989
# 990
# 991
# 991
# 993
# 993
# 996
# 1000
# 1000
# 1002
# 1002
# 606826663
# 1004
# 1005
# 1006
# 1007
# 1008
# 1008
# 1009
# 1010
# 1011
# 1011
# 1014
# 1014
# 1015
# 1016
# 1017
# 1017
# 1018
# 1018
# 1020
# 1021
# 1022
# 1023
# 1025
# 1026
# 1027
# 1027
# 1029
# 1030
# 1031
# 1033
# 1035
# 1037
# 1038
# 1039
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1051
# 1052
# 1054
# 1056
# 1057
# 1057
# 1058
# 1060
# 1061
# 1062
# 1065
# 1065
# 1066
# 1069
# 1070
# 1072
# 1073
# 1073
# 1074
# 1077
# 1079
# 1080
# 1080
# 1081
# 863
# 1084
# 1085
# 1086
# 1088
# 1089
# 1090
# 1091
# 1092
# 1093
# 1094
# 1096
# 1097
# 1098
# 1099
# 1099
# 1100
# 1100
# 1101
# 1102
# 525
# 1104
# 527696977
# 1106
# 1107
# 1108
# 1109
# 1111
# 1113
# 1114
# 1116
# 1117
# 1117
# 1120
# 1121
# 1123
# 1125
# 1126
# 1127
# 1128
# 1129
# 1129
# 1132
# 1132
# 1139
# 607344834
# 198
# 599626923
# 599626927
# 449
# 381
# 202
# 563807435
# 563807439
# 690
# 206
# 1064
# 484682520
# 549
# 607344850
# 768
# 768
# 607344854
# 217
# 607344858
# 453
# 453
# 222
# 606826647
# 917
# 917
# 576
# 526157192
# 388
# 388
# 526157196
# 1041
# 429
# 580
# 705
# 705
# 496345672
# 182305697
# 931
# 933
# 933
# 614454277
# 595
# 776
# 776
# 526322264
# 560581551
# 945
# 606826655
# 482
# 951
# 611
# 147
# 955
# 911
# 737
# 737
# 484682470
# 701
# 701
# 784
# 466
# 629
# 312782578
# 312782594
# 312782598
# 312782604
# 301
# 312782608
# 1083
# 1083
# 312782612
# 312782616
# 312782620
# 312782624
# 312782628
# 312782628
# 312782632
# 312782636
# 312782640
# 549009203
# 312782644
# 312782648
# 549009211
# 312782652
# 549009215
# 549009219
# 549009223
# 549009227
# 589508447
# 589508451
# 998
# 589508455
# 484682516
# 190
# 10703
# 665
# 237
# 484682528
# 333
# 436
# 576073699
# 576073704
# 681
# 477
# 709
# 709
